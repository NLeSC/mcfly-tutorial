# %%
import numpy as np
import os
import sys
import pandas as pd

DATA = 'C:\\OneDrive - Netherlands eScience Center\\Project_mcfly\\data\\processed'
CODE = 'C:\\OneDrive - Netherlands eScience Center\\Project_mcfly\\mcfly\\mcfly'
sys.path.append(CODE)

# %%
import modelgen, find_architecture

# %% [markdown]
# # Experiment 1: RacketSports dataset

# %% [markdown]
# ## Load pre-processed dataset

# %%
dataset_name = 'RacketSports_'

X_train = np.load(os.path.join(DATA, dataset_name + 'X_train.npy'))
X_val = np.load(os.path.join(DATA, dataset_name + 'X_val.npy'))
X_test = np.load(os.path.join(DATA, dataset_name + 'X_test.npy'))
y_train = np.load(os.path.join(DATA, dataset_name + 'y_train.npy'))
y_val = np.load(os.path.join(DATA, dataset_name + 'y_val.npy'))
y_test = np.load(os.path.join(DATA, dataset_name + 'y_test.npy'))

# %%
X_train.shape
# Out:
# (151, 30, 6)

# %%
labels_unique = list(set(y_train))
print("Unique labels:", labels_unique)
# Out:
# Unique labels: ['Badminton_Smash', 'Badminton_Clear', 'Squash_ForehandBoast', 'Squash_BackhandBoast']

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(labels_unique)
lb.classes_
# Out:
# array(['Badminton_Clear', 'Badminton_Smash', 'Squash_BackhandBoast',
#        'Squash_ForehandBoast'], dtype='<U20')

# %%
y_train_binary = lb.fit_transform(y_train)
y_val_binary = lb.fit_transform(y_val)
y_test_binary = lb.fit_transform(y_test)

# %% [markdown]
# ## Create models

# %%
num_classes = y_train_binary.shape[1]

models = modelgen.generate_models(X_train.shape,
                                  number_of_classes=num_classes,
                                  number_of_models = 8)
# Out:
# Set maximum kernel size for InceptionTime models to number of timesteps.

# %%
models
# Out:
# [(<tensorflow.python.keras.engine.sequential.Sequential at 0x250c0951400>,
#   {'learning_rate': 0.002484154084388252,
#    'regularization_rate': 0.011546207293635275,
#    'filters': [71, 59],
#    'lstm_dims': [66, 54, 77, 25]},
#   'DeepConvLSTM'),
#  (<tensorflow.python.keras.engine.training.Model at 0x250c6770710>,
#   {'learning_rate': 0.09141080390808691,
#    'regularization_rate': 0.01832585673080127,
#    'network_depth': 3,
#    'max_filters_number': 247,
#    'max_kernel_size': 29},
#   'ResNet'),
#  (<tensorflow.python.keras.engine.sequential.Sequential at 0x250c67b9b38>,
#   {'learning_rate': 0.026280359241086435,
#    'regularization_rate': 0.018560286968579087,
#    'filters': array([86, 61, 68, 75, 51, 79, 54]),
#    'fc_hidden_nodes': 1236},
#   'CNN'),
#  (<tensorflow.python.keras.engine.training.Model at 0x250c7ec7f98>,
#   {'learning_rate': 0.00010010692438366147,
#    'regularization_rate': 0.00073533843724182,
#    'network_depth': 4,
#    'filters_number': 64,
#    'max_kernel_size': 25},
#   'InceptionTime'),
#  (<tensorflow.python.keras.engine.sequential.Sequential at 0x250c7f11780>,
#   {'learning_rate': 0.008734446279641641,
#    'regularization_rate': 0.013188981713008639,
#    'filters': [97, 17],
#    'lstm_dims': [40, 55, 65, 88, 40]},
#   'DeepConvLSTM'),
#  (<tensorflow.python.keras.engine.training.Model at 0x250cadf8898>,
#   {'learning_rate': 0.009462558480521481,
#    'regularization_rate': 0.0010718396739470006,
#    'network_depth': 3,
#    'filters_number': 83,
#    'max_kernel_size': 28},
#   'InceptionTime'),
#  (<tensorflow.python.keras.engine.sequential.Sequential at 0x250cae4b208>,
#   {'learning_rate': 0.015862398291812085,
#    'regularization_rate': 0.08756658122197335,
#    'filters': array([11, 33, 36, 51, 29, 19, 29]),
#    'fc_hidden_nodes': 24},
#   'CNN'),
#  (<tensorflow.python.keras.engine.training.Model at 0x250cca30f28>,
#   {'learning_rate': 0.0004226466303253857,
#    'regularization_rate': 0.04624242460502102,
#    'network_depth': 4,
#    'max_filters_number': 192,
#    'max_kernel_size': 21},
#   'ResNet')]

# %%
metric = models[0][0].metrics

# %%
metric.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d77d2ac19e56> in <module>()
# ----> 1 metric.name
#
# AttributeError: 'list' object has no attribute 'name'

# %%
resultpath = 'C:\\OneDrive - Netherlands eScience Center\\Project_mcfly\\trained_models'
outputfile = os.path.join(resultpath, 'modelcomparison_RaketSports01.json')
histories, val_accuracies, val_losses = find_architecture.train_models_on_samples(X_train, y_train_binary,
                                                                           X_val, y_val_binary,
                                                                           models,nr_epochs=50,
                                                                           subset_size=-1,
                                                                           verbose=True,
                                                                           outputfile=outputfile)
print('Details of the training process were stored in ',outputfile)
# Out:
# Training model 0 DeepConvLSTM
# Train on 150 samples, validate on 75 samples
# Epoch 1/50
# 150/150 [==============================] - 8s 52ms/step - loss: 2.9021 - acc: 0.2867 - val_loss: 2.5634 - val_acc: 0.6133
# Epoch 2/50
# 150/150 [==============================] - 1s 8ms/step - loss: 2.1561 - acc: 0.7933 - val_loss: 2.0115 - val_acc: 0.6133
# Epoch 3/50
# 150/150 [==============================] - 1s 8ms/step - loss: 2.0344 - acc: 0.6533 - val_loss: 1.7750 - val_acc: 0.6800
# Epoch 4/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.9332 - acc: 0.6400 - val_loss: 2.5602 - val_acc: 0.4267
# Epoch 5/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.6572 - acc: 0.7200 - val_loss: 1.7523 - val_acc: 0.6400
# Epoch 6/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.4715 - acc: 0.7867 - val_loss: 1.7600 - val_acc: 0.6800
# Epoch 7/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.3022 - acc: 0.8400 - val_loss: 1.7078 - val_acc: 0.6933
# Epoch 8/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.2708 - acc: 0.8467 - val_loss: 1.3221 - val_acc: 0.7733
# Epoch 9/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.1994 - acc: 0.8933 - val_loss: 1.3622 - val_acc: 0.7333
# Epoch 10/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.1259 - acc: 0.9067 - val_loss: 1.3870 - val_acc: 0.7067
# Epoch 32/50
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0149 - acc: 1.0000 - val_loss: 0.2835 - val_acc: 0.9067
# Epoch 33/50
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0153 - acc: 1.0000 - val_loss: 0.3291 - val_acc: 0.8400
# Epoch 34/50
# 150/150 [==============================] - 1s 6ms/step - loss: 0.0151 - acc: 1.0000 - val_loss: 0.2993 - val_acc: 0.8933
# Epoch 00034: early stopping
# Training model 4 DeepConvLSTM
# Train on 150 samples, validate on 75 samples
# Epoch 1/50
# 150/150 [==============================] - 9s 59ms/step - loss: 2.7315 - acc: 0.3800 - val_loss: 2.5499 - val_acc: 0.2933
# Epoch 2/50
# 150/150 [==============================] - 2s 11ms/step - loss: 2.6476 - acc: 0.4333 - val_loss: 2.3621 - val_acc: 0.3733
# Epoch 3/50
# 150/150 [==============================] - 2s 10ms/step - loss: 2.1922 - acc: 0.3733 - val_loss: 2.2900 - val_acc: 0.2933
# Epoch 4/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.8545 - acc: 0.5067 - val_loss: 2.3376 - val_acc: 0.2667
# Epoch 5/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.5991 - acc: 0.5467 - val_loss: 1.4052 - val_acc: 0.5200
# Epoch 6/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.3704 - acc: 0.5333 - val_loss: 1.3801 - val_acc: 0.4667
# Epoch 7/50
# 150/150 [==============================] - 2s 10ms/step - loss: 1.3362 - acc: 0.4933 - val_loss: 1.4967 - val_acc: 0.5200
# Epoch 8/50
# 150/150 [==============================] - 1s 10ms/step - loss: 1.3126 - acc: 0.4867 - val_loss: 1.1882 - val_acc: 0.5067
# Epoch 9/50
# 150/150 [==============================] - 2s 10ms/step - loss: 1.3698 - acc: 0.4533 - val_loss: 1.3043 - val_acc: 0.3867
# Epoch 10/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.2099 - acc: 0.5133 - val_loss: 1.0784 - val_acc: 0.7600
# Epoch 11/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.0882 - acc: 0.5600 - val_loss: 0.9843 - val_acc: 0.6133
# Epoch 12/50
# 150/150 [==============================] - 2s 10ms/step - loss: 0.9887 - acc: 0.6000 - val_loss: 0.9823 - val_acc: 0.5867
# Epoch 13/50
# 150/150 [==============================] - 2s 10ms/step - loss: 0.9722 - acc: 0.6133 - val_loss: 1.6547 - val_acc: 0.5067
# Epoch 14/50
# 150/150 [==============================] - 2s 10ms/step - loss: 1.0616 - acc: 0.5800 - val_loss: 1.1621 - val_acc: 0.5067
# Epoch 15/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.2817 - acc: 0.5667 - val_loss: 1.5004 - val_acc: 0.4400
# Epoch 16/50
# 150/150 [==============================] - 2s 10ms/step - loss: 1.3174 - acc: 0.5000 - val_loss: 1.5302 - val_acc: 0.4800
# Epoch 17/50
# Epoch 13/50
# 150/150 [==============================] - 0s 3ms/step - loss: 1.5851 - acc: 0.7800 - val_loss: 2.3002 - val_acc: 0.4667
# Epoch 00013: early stopping
# Training model 7 ResNet
# Train on 150 samples, validate on 75 samples
# Epoch 1/50
# 150/150 [==============================] - 9s 58ms/step - loss: 0.9370 - acc: 0.6000 - val_loss: 2.3878 - val_acc: 0.2667
# Epoch 2/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.3051 - acc: 0.8733 - val_loss: 1.2553 - val_acc: 0.4667
# Epoch 3/50
# 150/150 [==============================] - 2s 13ms/step - loss: 0.1325 - acc: 0.9867 - val_loss: 0.8138 - val_acc: 0.6400
# Epoch 4/50
# 150/150 [==============================] - 2s 13ms/step - loss: 0.0750 - acc: 0.9800 - val_loss: 0.9025 - val_acc: 0.6000
# Epoch 5/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0255 - acc: 1.0000 - val_loss: 1.1877 - val_acc: 0.5467
# Epoch 6/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0174 - acc: 1.0000 - val_loss: 0.9343 - val_acc: 0.6800
# Epoch 7/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0071 - acc: 1.0000 - val_loss: 0.9229 - val_acc: 0.6933
# Epoch 8/50
# 150/150 [==============================] - 2s 10ms/step - loss: 0.0083 - acc: 1.0000 - val_loss: 0.6842 - val_acc: 0.7600
# Epoch 9/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.6390 - val_acc: 0.8000
# Epoch 10/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.5943 - val_acc: 0.8133
# Epoch 11/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0069 - acc: 1.0000 - val_loss: 0.4796 - val_acc: 0.8267
# Epoch 12/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.4588 - val_acc: 0.8267
# Epoch 13/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0068 - acc: 1.0000 - val_loss: 0.4813 - val_acc: 0.8400
# Epoch 14/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.3707 - val_acc: 0.8400
# Epoch 15/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.5682 - val_acc: 0.8000
# Epoch 16/50
# 150/150 [==============================] - 2s 13ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.3443 - val_acc: 0.8800
# Epoch 17/50
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.4108 - val_acc: 0.8800
# Epoch 18/50
# 150/150 [==============================] - 2s 14ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 0.3089 - val_acc: 0.9067
# Epoch 19/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.5977 - val_acc: 0.8000
# Epoch 20/50
# 150/150 [==============================] - 2s 13ms/step - loss: 0.0222 - acc: 0.9933 - val_loss: 0.4797 - val_acc: 0.8400
# Epoch 21/50
# 150/150 [==============================] - 2s 13ms/step - loss: 0.0083 - acc: 1.0000 - val_loss: 0.8506 - val_acc: 0.8133
# Epoch 22/50
# 150/150 [==============================] - 2s 12ms/step - loss: 0.0600 - acc: 0.9800 - val_loss: 0.7760 - val_acc: 0.7867
# Epoch 23/50
# 150/150 [==============================] - 2s 11ms/step - loss: 0.0895 - acc: 0.9600 - val_loss: 2.1593 - val_acc: 0.6667
# Epoch 00023: early stopping
# Details of the training process were stored in  C:\OneDrive - Netherlands eScience Center\Project_mcfly\trained_models\modelcomparison_RaketSports01.json

# %%
modelcomparisons = pd.DataFrame({'model':[str(params) for model, params, model_types in models],
                                'model-type':[str(model_types) for model, params, model_types in models],
                               'train_acc': [history.history['acc'][-1] for history in histories],
                               'train_loss': [history.history['loss'][-1] for history in histories],
                               'val_acc': [history.history['val_acc'][-1] for history in histories],
                               'val_loss': [history.history['val_loss'][-1] for history in histories]
                               })
modelcomparisons.to_csv(os.path.join(resultpath, 'modelcomparisons_RaketSports01.csv'))

modelcomparisons
# Out:
#                                                model     model-type  \
# 0  {'learning_rate': 0.002484154084388252, 'regul...   DeepConvLSTM
# 1  {'learning_rate': 0.09141080390808691, 'regula...         ResNet
# 2  {'learning_rate': 0.026280359241086435, 'regul...            CNN
# 3  {'learning_rate': 0.00010010692438366147, 'reg...  InceptionTime
# 4  {'learning_rate': 0.008734446279641641, 'regul...   DeepConvLSTM
# 5  {'learning_rate': 0.009462558480521481, 'regul...  InceptionTime
# 6  {'learning_rate': 0.015862398291812085, 'regul...            CNN
# 7  {'learning_rate': 0.0004226466303253857, 'regu...         ResNet
#
#    train_acc  train_loss   val_acc  val_loss
# 0   0.973333    0.550228  0.693333  1.525891
# 1   0.893333    0.281075  0.626667  1.845222
# 2   0.700000    2.821229  0.226667  3.374627
# 3   1.000000    0.015094  0.893333  0.299265
# 4   0.466667    1.376363  0.493333  1.437387
# 5   0.913333    0.209541  0.520000  7.183406
# 6   0.780000    1.585142  0.466667  2.300151
# 7   0.960000    0.089470  0.666667  2.159332

# %%
models[3][0].summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 30, 6)        0
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 30, 32)       192         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 30, 6)        0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 30, 64)       51200       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 30, 64)       24576       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 30, 64)       12288       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 30, 64)       384         max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 30, 256)      0           conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 30, 256)      1024        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 30, 256)      0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 30, 32)       8192        activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 30, 256)      0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 30, 64)       51200       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 30, 64)       24576       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 30, 64)       12288       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 30, 64)       16384       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 30, 256)      0           conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
#                                                                  conv1d_25[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 30, 256)      1024        concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 30, 256)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 30, 32)       8192        activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 30, 256)      0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 30, 64)       51200       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 30, 64)       24576       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 30, 64)       12288       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 30, 64)       16384       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 30, 256)      0           conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
#                                                                  conv1d_30[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 30, 256)      1536        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 30, 256)      1024        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 30, 256)      1024        conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 30, 256)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 30, 256)      0           batch_normalization_24[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 30, 256)      0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 30, 32)       8192        activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 30, 256)      0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 30, 64)       51200       conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 30, 64)       24576       conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 30, 64)       12288       conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 30, 64)       16384       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 30, 256)      0           conv1d_34[0][0]
#                                                                  conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
#                                                                  conv1d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 30, 256)      1024        concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 30, 256)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 256)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            1028        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 434,244
# Trainable params: 431,684
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
